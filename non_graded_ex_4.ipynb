# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time


detail_deck = {
    '01': {'Name': 'Diablo', 'Health': 100, 'Attack': 90, 'Defense': 60},
    '02': {'Name': 'Medusa', 'Health': 100, 'Attack': 70, 'Defense': 70},
    '03': {'Name': 'Jester', 'Health': 120, 'Attack': 60, 'Defense': 90},
    '04': {'Name': 'Troll', 'Health': 150, 'Attack': 40, 'Defense': 94},
    '05': {'Name': 'Specter', 'Health': 100, 'Attack': 70, 'Defense': 70},
    '06': {'Name': 'Mist', 'Health': 100, 'Attack': 75, 'Defense': 65},
    '07': {'Name': 'Savage', 'Health': 100, 'Attack': 90, 'Defense': 50},
    '08': {'Name': 'Marauder', 'Health': 100, 'Attack': 85, 'Defense': 50},
    '09': {'Name': 'Wimp', 'Health': 110, 'Attack': 40, 'Defense': 85},
    '10': {'Name': 'Sorcerer', 'Health': 100, 'Attack': 70, 'Defense': 55},
}

detail_deck2 = {
    '01': {'Name': 'Diablo', 'Health': 100, 'Attack': 90, 'Defense': 60},
    '02': {'Name': 'Medusa', 'Health': 100, 'Attack': 70, 'Defense': 70},
    '03': {'Name': 'Jester', 'Health': 120, 'Attack': 60, 'Defense': 90},
    '04': {'Name': 'Troll', 'Health': 150, 'Attack': 40, 'Defense': 94},
    '05': {'Name': 'Specter', 'Health': 100, 'Attack': 70, 'Defense': 70},
    '06': {'Name': 'Mist', 'Health': 100, 'Attack': 75, 'Defense': 65},
    '07': {'Name': 'Savage', 'Health': 100, 'Attack': 90, 'Defense': 50},
    '08': {'Name': 'Marauder', 'Health': 100, 'Attack': 85, 'Defense': 50},
    '09': {'Name': 'Wimp', 'Health': 110, 'Attack': 40, 'Defense': 85},
    '10': {'Name': 'Sorcerer', 'Health': 100, 'Attack': 70, 'Defense': 55},
}

card_deck = list(detail_deck.keys())
card_deck2 = list(detail_deck2.keys())
deck_size = 5


def print_card(card_id):
    card = detail_deck[card_id]
    print(f"Name: {card['Name']}, Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']}")

def print_opponent_card(card_id):
    card = detail_deck2[card_id]
    print(f"Name: {card['Name']}, Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']}")


def fight(player_card_id, opponent_card_id):
    player_card = detail_deck[player_card_id]
    opponent_card = detail_deck2[opponent_card_id]

    
    print(f"Your {player_card['Name']} attacks the opponent's {opponent_card['Name']}!")
    if player_card['Attack'] <= opponent_card['Defense']:
        opponent_card['Defense'] -= player_card['Attack']
        print(f"Opponent's {opponent_card['Name']}'s defense decreased to {opponent_card['Defense']}.")
    else:
        damage_to_health = player_card['Attack'] - opponent_card['Defense']
        opponent_card['Health'] -= damage_to_health
        opponent_card['Defense'] = 0
        print(f"Opponent's {opponent_card['Name']}'s defense is now 0, and its health is {opponent_card['Health']}.")


    if opponent_card['Health'] <= 0:
        print(f"Opponent's {opponent_card['Name']} is defeated!")
        return True
    return False

def opponent_fight(opponent_card_id, player_card_id):
    player_card = detail_deck[player_card_id]
    opponent_card = detail_deck2[opponent_card_id]


    print(f"Opponent's {opponent_card['Name']} attacks the your {player_card['Name']}!")
    if opponent_card['Attack'] <= player_card['Defense']:
        player_card['Defense'] -= opponent_card['Attack']
        print(f"Your {player_card['Name']}'s defense decreased to {player_card['Defense']}.")
    else:
        damage_to_health = opponent_card['Attack'] - player_card['Defense']
        player_card['Health'] -= damage_to_health
        player_card['Defense'] = 0
        print(f"Your {player_card['Name']}'s defense is now 0, and its health is {player_card['Health']}.")


    if player_card['Health'] <= 0:
        print(f"Your {player_card['Name']} is defeated!")
        return True
    return False


def game():
    print("Welcome to the Card RPG Battle!")

    player_deck = random.sample(card_deck, deck_size)
    opponent_deck = random.sample(card_deck2, deck_size)

    while player_deck and opponent_deck:
        print("\nYour cards:")
        for idx, card_id in enumerate(player_deck):
            print(f"{idx + 1}.", end=" ")
            print_card(card_id)
        
        opponent_card_id = random.choice(opponent_deck)
        print("\nOpponent's card:")
        print_opponent_card(opponent_card_id)

        while True:
            card_input = input("\nPick a card from your deck to fight against (enter card number): ")
            if card_input.isdigit() and 1 <= int(card_input) <= len(player_deck):
                break
            else:
                print("Invalid input, please enter a valid number corresponding to your card.")

        card_choose = int(card_input) - 1
        player_card_id = player_deck[card_choose]

        if fight(player_card_id, opponent_card_id):
            opponent_deck.remove(opponent_card_id)

        if not opponent_deck:
            print("\nCongratulations! You defeated all the opponent's cards!")
            break

        time.sleep(3)

        print("\nOpponent's turn to attack!")
        
        opponent_card_id = random.choice(opponent_deck)
        player_card_id = random.choice(player_deck)

        if opponent_fight(opponent_card_id, player_card_id):
            player_deck.remove(player_card_id)

        if not player_deck:
            print("\nOh no! You've lost all your cards. The opponent wins.")
            break

        time.sleep(3)



game()
# Out:
# Welcome to the Card RPG Battle!
#
# Your cards:
# 1. Name: Savage, Health: 100, Attack: 90, Defense: 50
# 2. Name: Specter, Health: 100, Attack: 70, Defense: 70
# 3. Name: Medusa, Health: 100, Attack: 70, Defense: 70
# 4. Name: Mist, Health: 100, Attack: 75, Defense: 65
# 5. Name: Jester, Health: 120, Attack: 60, Defense: 90
# opp1. Name: Sorcerer, Health: 100, Attack: 70, Defense: 55
# opp2. Name: Mist, Health: 100, Attack: 75, Defense: 65
# opp3. Name: Savage, Health: 100, Attack: 90, Defense: 50
# opp4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# opp5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent's card:
# Name: Sorcerer, Health: 100, Attack: 70, Defense: 55
# Invalid input, please enter a valid number corresponding to your card.
# Your Savage attacks the opponent's Sorcerer!
# Opponent's Sorcerer's defense is now 0, and its health is 65.
#
# Opponent's turn to attack!
# Opponent's Marauder attacks the your Jester!
# Your Jester's defense decreased to 5.
#
# Your cards:
# 1. Name: Savage, Health: 100, Attack: 90, Defense: 50
# 2. Name: Specter, Health: 100, Attack: 70, Defense: 70
# 3. Name: Medusa, Health: 100, Attack: 70, Defense: 70
# 4. Name: Mist, Health: 100, Attack: 75, Defense: 65
# 5. Name: Jester, Health: 120, Attack: 60, Defense: 5
# opp1. Name: Sorcerer, Health: 100, Attack: 70, Defense: 55
# opp2. Name: Mist, Health: 100, Attack: 75, Defense: 65
# opp3. Name: Savage, Health: 100, Attack: 90, Defense: 50
# opp4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# opp5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent's card:
# Name: Wimp, Health: 110, Attack: 40, Defense: 85
# Your Savage attacks the opponent's Wimp!
# Opponent's Wimp's defense is now 0, and its health is 105.
#
# Opponent's turn to attack!
# Opponent's Wimp attacks the your Specter!
# Your Specter's defense decreased to 30.
#
# Your cards:
# 1. Name: Savage, Health: 100, Attack: 90, Defense: 50
# 2. Name: Specter, Health: 100, Attack: 70, Defense: 30
# 3. Name: Medusa, Health: 100, Attack: 70, Defense: 70
# 4. Name: Mist, Health: 100, Attack: 75, Defense: 65
# 5. Name: Jester, Health: 120, Attack: 60, Defense: 5
# opp1. Name: Sorcerer, Health: 100, Attack: 70, Defense: 55
# opp2. Name: Mist, Health: 100, Attack: 75, Defense: 65
# opp3. Name: Savage, Health: 100, Attack: 90, Defense: 50
# opp4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# opp5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent's card:
# Name: Wimp, Health: 105, Attack: 40, Defense: 0
# Your Savage attacks the opponent's Wimp!
# Opponent's Wimp's defense is now 0, and its health is 15.
#
# Opponent's turn to attack!
# Opponent's Savage attacks the your Medusa!
# Your Medusa's defense is now 0, and its health is 80.
#
# Your cards:
# 1. Name: Savage, Health: 100, Attack: 90, Defense: 50
# 2. Name: Specter, Health: 100, Attack: 70, Defense: 30
# 3. Name: Medusa, Health: 80, Attack: 70, Defense: 0
# 4. Name: Mist, Health: 100, Attack: 75, Defense: 65
# 5. Name: Jester, Health: 120, Attack: 60, Defense: 5
# opp1. Name: Sorcerer, Health: 100, Attack: 70, Defense: 55
# opp2. Name: Mist, Health: 100, Attack: 75, Defense: 65
# opp3. Name: Savage, Health: 100, Attack: 90, Defense: 50
# opp4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# opp5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent's card:
# Name: Savage, Health: 100, Attack: 90, Defense: 50
# Your Savage attacks the opponent's Savage!
# Opponent's Savage's defense is now 0, and its health is 60.
#
# Opponent's turn to attack!
# Opponent's Sorcerer attacks the your Savage!
# Your Savage's defense is now 0, and its health is 80.
#
# Your cards:
# 1. Name: Savage, Health: 80, Attack: 90, Defense: 0
# 2. Name: Specter, Health: 100, Attack: 70, Defense: 30
# 3. Name: Medusa, Health: 80, Attack: 70, Defense: 0
# 4. Name: Mist, Health: 100, Attack: 75, Defense: 65
# 5. Name: Jester, Health: 120, Attack: 60, Defense: 5
# opp1. Name: Sorcerer, Health: 100, Attack: 70, Defense: 55
# opp2. Name: Mist, Health: 100, Attack: 75, Defense: 65
# opp3. Name: Savage, Health: 80, Attack: 90, Defense: 0
# opp4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# opp5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent's card:
# Name: Savage, Health: 60, Attack: 90, Defense: 0
